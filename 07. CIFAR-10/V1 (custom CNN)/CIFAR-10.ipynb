# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout, MaxPool2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Importing dataset

# %%
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.cifar10.load_data()

# %%
y_test = Y_test

# %%
ran = np.random.randint(0, X_train.shape[0])
print(Y_train[ran])
plt.imshow(X_train[ran])
# Out:
# [4]

# %% [markdown]
# ### Data preprocessing

# %%
print(X_train.shape)
print(Y_test[0])
print(X_test.shape)
# Out:
# (50000, 32, 32, 3)
# [3]
# (10000, 32, 32, 3)

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

# %%
Y_train = tf.keras.utils.to_categorical(Y_train)
Y_test = tf.keras.utils.to_categorical(Y_test)

# %%
print(Y_test[0])
# Out:
# [3]

# %% [markdown]
# ### Data Augmentation

# %%
img_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    validation_split=0.2
)

# %% [markdown]
# ## Designing model

# %%
model = tf.keras.Sequential([
        Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
        BatchNormalization(),
        Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2), padding='valid'),

        Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPool2D(pool_size=(2, 2), padding='valid'),

        Flatten(),
        Dropout(0.2),
        Dense(1024, activation='relu'),
        Dropout(0.2),
        Dense(10, activation='softmax')
])

# %% [markdown]
# ### Compilling model

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 4,271,914
# Trainable params: 4,271,530
# Non-trainable params: 384
# _________________________________________________________________

# %% [markdown]
# ## Train model

# %%
model.fit(X_train, Y_train, epochs=50, verbose=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.8419 - accuracy: 0.7089 - val_loss: 0.8238 - val_accuracy: 0.7215
# Epoch 2/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.6863 - accuracy: 0.7642 - val_loss: 0.7930 - val_accuracy: 0.7308
# Epoch 3/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.5655 - accuracy: 0.8039 - val_loss: 0.6842 - val_accuracy: 0.7647
# Epoch 4/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.4599 - accuracy: 0.8404 - val_loss: 0.8167 - val_accuracy: 0.7485
# Epoch 5/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.3753 - accuracy: 0.8695 - val_loss: 0.7428 - val_accuracy: 0.7657
# Epoch 6/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.3010 - accuracy: 0.8961 - val_loss: 0.7171 - val_accuracy: 0.7894
# Epoch 7/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2395 - accuracy: 0.9176 - val_loss: 0.7755 - val_accuracy: 0.7841
# Epoch 8/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.2041 - accuracy: 0.9318 - val_loss: 0.8802 - val_accuracy: 0.7661
# Epoch 9/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1842 - accuracy: 0.9368 - val_loss: 0.8797 - val_accuracy: 0.7732
# Epoch 10/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1597 - accuracy: 0.9456 - val_loss: 0.7961 - val_accuracy: 0.7928
# Epoch 11/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.1418 - accuracy: 0.9523 - val_loss: 0.8986 - val_accuracy: 0.7904
# Epoch 12/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1363 - accuracy: 0.9540 - val_loss: 0.8893 - val_accuracy: 0.7820
# Epoch 13/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1201 - accuracy: 0.9601 - val_loss: 0.8727 - val_accuracy: 0.7857
# Epoch 14/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1087 - accuracy: 0.9649 - val_loss: 0.9357 - val_accuracy: 0.7882
# Epoch 15/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1027 - accuracy: 0.9650 - val_loss: 0.8793 - val_accuracy: 0.7987
# Epoch 16/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0968 - accuracy: 0.9678 - val_loss: 0.9037 - val_accuracy: 0.7974
# Epoch 17/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0951 - accuracy: 0.9685 - val_loss: 0.9231 - val_accuracy: 0.7995
# Epoch 18/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0814 - accuracy: 0.9731 - val_loss: 0.9423 - val_accuracy: 0.7948
# Epoch 19/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0806 - accuracy: 0.9735 - val_loss: 1.0364 - val_accuracy: 0.7889
# Epoch 20/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0772 - accuracy: 0.9746 - val_loss: 1.0300 - val_accuracy: 0.7958
# Epoch 21/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0755 - accuracy: 0.9758 - val_loss: 1.2523 - val_accuracy: 0.7562
# Epoch 22/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0690 - accuracy: 0.9775 - val_loss: 0.9591 - val_accuracy: 0.7942
# Epoch 23/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0709 - accuracy: 0.9773 - val_loss: 1.0524 - val_accuracy: 0.7955
# Epoch 24/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0639 - accuracy: 0.9787 - val_loss: 0.9287 - val_accuracy: 0.7975
# Epoch 25/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0671 - accuracy: 0.9780 - val_loss: 0.9167 - val_accuracy: 0.8031
# Epoch 26/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0583 - accuracy: 0.9808 - val_loss: 0.9978 - val_accuracy: 0.8044
# Epoch 27/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0593 - accuracy: 0.9806 - val_loss: 1.0722 - val_accuracy: 0.7861
# Epoch 28/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0521 - accuracy: 0.9832 - val_loss: 0.9446 - val_accuracy: 0.8005
# Epoch 29/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0536 - accuracy: 0.9822 - val_loss: 1.0742 - val_accuracy: 0.7967
# Epoch 30/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0499 - accuracy: 0.9840 - val_loss: 0.9939 - val_accuracy: 0.8029
# Epoch 31/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0500 - accuracy: 0.9841 - val_loss: 1.0259 - val_accuracy: 0.8066
# Epoch 32/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0521 - accuracy: 0.9828 - val_loss: 1.0194 - val_accuracy: 0.8028
# Epoch 33/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0463 - accuracy: 0.9853 - val_loss: 0.9450 - val_accuracy: 0.8037
# Epoch 34/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0458 - accuracy: 0.9854 - val_loss: 0.9490 - val_accuracy: 0.8024
# Epoch 35/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.0487 - accuracy: 0.9841 - val_loss: 1.0717 - val_accuracy: 0.8012
# Epoch 36/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0465 - accuracy: 0.9851 - val_loss: 0.9399 - val_accuracy: 0.7965
# Epoch 37/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0463 - accuracy: 0.9849 - val_loss: 1.0588 - val_accuracy: 0.7993
# Epoch 38/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0449 - accuracy: 0.9854 - val_loss: 0.9427 - val_accuracy: 0.7900
# Epoch 39/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0414 - accuracy: 0.9862 - val_loss: 0.9938 - val_accuracy: 0.8033
# Epoch 40/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0417 - accuracy: 0.9865 - val_loss: 1.0920 - val_accuracy: 0.8088
# Epoch 41/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0405 - accuracy: 0.9871 - val_loss: 1.3088 - val_accuracy: 0.7923
# Epoch 42/50
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.0388 - accuracy: 0.9877 - val_loss: 1.0911 - val_accuracy: 0.8005
# Epoch 43/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 1.0773 - val_accuracy: 0.7924
# Epoch 44/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0361 - accuracy: 0.9882 - val_loss: 1.1941 - val_accuracy: 0.8004
# Epoch 45/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0403 - accuracy: 0.9877 - val_loss: 1.0823 - val_accuracy: 0.8013
# Epoch 46/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0408 - accuracy: 0.9873 - val_loss: 1.1714 - val_accuracy: 0.8038
# Epoch 47/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.0369 - accuracy: 0.9887 - val_loss: 1.3644 - val_accuracy: 0.7937
# Epoch 48/50
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.0369 - accuracy: 0.9883 - val_loss: 1.2672 - val_accuracy: 0.7974
# Epoch 49/50
# 1563/1563 [==============================] - 23s 15ms/step - loss: 0.0368 - accuracy: 0.9883 - val_loss: 1.2279 - val_accuracy: 0.8072
# Epoch 50/50
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.0341 - accuracy: 0.9893 - val_loss: 1.3687 - val_accuracy: 0.7991

# %%
model.fit(img_generator.flow(X_train, Y_train, batch_size=64), epochs=50, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.6752 - accuracy: 0.7683 - val_loss: 0.5626 - val_accuracy: 0.8125
# Epoch 2/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0
50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.4491 - accuracy: 0.8471 - val_loss: 0.5278 - val_accuracy: 0.8392
# Epoch 29/50
# 782/782 [==============================] - 46s 59ms/step - loss: 0.4401 - accuracy: 0.8479 - val_loss: 0.5098 - val_accuracy: 0.8370
# Epoch 30/50
# 782/782 [==============================] - 45s 58ms/step - loss: 0.4393 - accuracy: 0.8480 - val_loss: 0.5312 - val_accuracy: 0.8332
# Epoch 31/50
# 782/782 [==============================] - 45s 57ms/step - loss: 0.4342 - accuracy: 0.8520 - val_loss: 0.4727 - val_accuracy: 0.8471
# Epoch 32/50
# 782/782 [==============================] - 44s 57ms/step - loss: 0.4290 - accuracy: 0.8526 - val_loss: 0.4997 - val_accuracy: 0.8410
# Epoch 33/50
# 782/782 [==============================] - 44s 57ms/step - loss: 0.4237 - accuracy: 0.8542 - val_loss: 0.5165 - val_accuracy: 0.8387
# Epoch 34/50
# 782/782 [==============================] - 45s 57ms/step - loss: 0.4221 - accuracy: 0.8543 - val_loss: 0.5119 - val_accuracy: 0.8364
# Epoch 35/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4165 - accuracy: 0.8554 - val_loss: 0.5135 - val_accuracy: 0.8388
# Epoch 36/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4224 - accuracy: 0.8522 - val_loss: 0.4599 - val_accuracy: 0.8550
# Epoch 37/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4150 - accuracy: 0.8570 - val_loss: 0.4754 - val_accuracy: 0.8473
# Epoch 38/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4147 - accuracy: 0.8555 - val_loss: 0.4561 - val_accuracy: 0.8603
# Epoch 39/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.4040 - accuracy: 0.8614 - val_loss: 0.4777 - val_accuracy: 0.8478
# Epoch 40/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4025 - accuracy: 0.8606 - val_loss: 0.5378 - val_accuracy: 0.8370
# Epoch 41/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.4022 - accuracy: 0.8598 - val_loss: 0.4690 - val_accuracy: 0.8515
# Epoch 42/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3987 - accuracy: 0.8635 - val_loss: 0.5421 - val_accuracy: 0.8375
# Epoch 43/50
# 782/782 [==============================] - 43s 56ms/step - loss: 0.3952 - accuracy: 0.8643 - val_loss: 0.4696 - val_accuracy: 0.8568
# Epoch 44/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3884 - accuracy: 0.8666 - val_loss: 0.4902 - val_accuracy: 0.8469
# Epoch 45/50
# 782/782 [==============================] - 44s 56ms/step - loss: 0.3892 - accuracy: 0.8657 - val_loss: 0.4751 - val_accuracy: 0.8506
# Epoch 46/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3855 - accuracy: 0.8668 - val_loss: 0.4789 - val_accuracy: 0.8518
# Epoch 47/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3800 - accuracy: 0.8679 - val_loss: 0.5057 - val_accuracy: 0.8437
# Epoch 48/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3796 - accuracy: 0.8684 - val_loss: 0.5312 - val_accuracy: 0.8373
# Epoch 49/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3789 - accuracy: 0.8695 - val_loss: 0.4867 - val_accuracy: 0.8443
# Epoch 50/50
# 782/782 [==============================] - 43s 55ms/step - loss: 0.3748 - accuracy: 0.8694 - val_loss: 0.5012 - val_accuracy: 0.8491

# %%
model = tf.keras.models.load_model('/content/custom_CNN.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              4195328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 4,271,914
# Trainable params: 4,271,530
# Non-trainable params: 384
# _________________________________________________________________
